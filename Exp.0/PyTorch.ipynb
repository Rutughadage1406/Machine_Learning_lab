# %% [markdown]
# **<h1>⚡ PyTorch Notebook</h1>**
#
# **<p>Deep Learning • Neural Networks • AI</p>**
# </div>
#
# # <img src="https://pytorch.org/assets/images/pytorch-logo.png" width="400">
#
# **### 🎯 Learning Outcomes**
# - Learn PyTorch fundamentals
# - Work with tensors
# - Build neural networks
# - Train and evaluate models
#
# > 💡 **Did You Know?**
# PyTorch is one of the most popular deep learning frameworks used in research and industry.

# %% [markdown]
# ---
#
# # **# 🌟 Introduction**
#
# **What is PyTorch? Why use it?**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
import torch
print("PyTorch Version:", torch.__version__)

# Expected Output:
# Displays installed PyTorch version.

# %% [markdown]
# ---
#
# ## **🌟 Tensors**
#
# **Creating tensors and basic operations**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
import torch
a=torch.tensor([[1,2],[3,4]])
b=torch.tensor([[5,6],[7,8]])
print(a)
print(b)

# %% [markdown]
# ---
#
# # 🌟 Tensor Operations
#
# **Arithmetic, reshape, matrix multiplication**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
import torch
x=torch.tensor([1,2,3])
y=torch.tensor([4,5,6])
print("Addition:",x+y)
print("Multiplication:",x*y)
print("Matrix Multiplication:")
print(torch.matmul(torch.tensor([[1.,2.]]),torch.tensor([[3.],[4.]])))
print(torch.arange(12).reshape(3,4))

# %% [markdown]
# ---
#
# # 🌟 Autograd
#
# **Automatic differentiation**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
import torch
x=torch.tensor(2.0,requires_grad=True)
y=x**3+2*x
y.backward()
print("Gradient:",x.grad)

# %% [markdown]
# ---
#
# # 🌟 Neural Networks
#
# **Creating models with nn.Module**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
import torch.nn as nn

model=nn.Sequential(
    nn.Linear(4,16),
    nn.ReLU(),
    nn.Linear(16,3)
)
print(model)

# %% [markdown]
# ---
#
# # 🌟 Training Loop
#
# **Loss, optimizer, backward propagation**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

X=torch.randn(20,4)
y=torch.randint(0,3,(20,))

model=nn.Sequential(nn.Linear(4,16),nn.ReLU(),nn.Linear(16,3))
criterion=nn.CrossEntropyLoss()
optimizer=optim.Adam(model.parameters(),lr=0.01)

for epoch in range(5):
    optimizer.zero_grad()
    outputs=model(X)
    loss=criterion(outputs,y)
    loss.backward()
    optimizer.step()
print("Training Complete")

# %% [markdown]
# ---
#
# # 🌟 Model Evaluation
#
# **Prediction and accuracy**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
with torch.no_grad():
    pred=model(X).argmax(dim=1)
    acc=(pred==y).float().mean()
print("Accuracy:",acc.item())

# %% [markdown]
# ---
#
# # 🌟 Applications
#
# **Computer Vision, NLP, Robotics**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
apps=[
"Computer Vision",
"Natural Language Processing",
"Generative AI",
"Healthcare",
"Robotics",
"Recommendation Systems"]
for a in apps:
    print("✔",a)

# %% [markdown]
# ---
#
# # 🌟 Mini Project
#
# **MNIST Digit Classifier**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
from torchvision.datasets import MNIST
from torchvision import transforms

dataset=MNIST(root='.',download=True,train=True,
              transform=transforms.ToTensor())

print("Training Samples:",len(dataset))
print("Image Shape:",dataset[0][0].shape)

# Exercise:
# Build a CNN for digit classification.

# %% [markdown]
# ---
#
# # 🌟 Quiz & Cheat Sheet
#
# **Revision**
#
# ```text
# Data → Tensor → Model → Training → Prediction
# ```
#
# 💡 **Did You Know?**
# - PyTorch builds dynamic computation graphs, making debugging easier.
#
# 📝 **Practice Exercise**
# - Modify the tensor values.
# - Change the number of hidden neurons.
# - Observe model performance.

# %%
# Cheat Sheet
# torch.tensor()
# torch.arange()
# torch.matmul()
# requires_grad=True
# nn.Sequential()
# nn.Linear()
# optimizer.step()
# loss.backward()
# torch.no_grad()

# %% [markdown]
# # **# 🎉 Thank You**
#
# ### Continue Learning
#
# Happy Deep Learning! 🚀
